# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding='latin-1')
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.groupby("Area")["Y2017"].sum().sort_values(ascending=True).head(7)
# Out:
# Area
# Sudan (former)               0.00
# Ethiopia PDR                 0.00
# Comoros                     59.84
# Seychelles                 442.34
# Sao Tome and Principe    12662.63
# Cabo Verde               14650.74
# Guinea-Bissau            19102.77
# Name: Y2017, dtype: float64

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd.DataFrame(lst, columns = col, index= [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
df["Y2014"].isnull().sum()
# Out:
# 1589

# %%
df.shape
# Out:
# (60943, 12)

# %%
df["Area"].nunique()
# Out:
# 49

# %%
df["Area"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
df["Element"].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
df.groupby("Area")("Element")["Y2015"].sum().sort_values(ascending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.groupby("Area")("Element")["Y2015"].sum().sort_values(ascending=True)
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
df.groupby("Element")["Y2017"].sum().sort_values(ascending=True)
# Out:
# Element
# Tourist consumption                            91.00
# Fat supply quantity (g/capita/day)          10253.84
# Protein supply quantity (g/capita/day)      11842.45
# Seed                                        24870.14
# Residuals                                   35500.00
# Food supply quantity (kg/capita/yr)         48690.04
# Stock Variation                             54316.91
# Other uses (non-food)                       91645.97
# Losses                                     160614.00
# Export Quantity                            182338.80
# Feed                                       223705.68
# Processing                                 292836.00
# Import Quantity                            294559.09
# Food supply (kcal/capita/day)              454681.00
# Total Population - Both sexes             1112641.00
# Food                                      1258888.28
# Production                                2030056.89
# Domestic supply quantity                  2088198.10
# ...

# %%
df.groupby("Element")["Y2016"].sum().sort_values(ascending=True)
# Out:
# Element
# Tourist consumption                            89.00
# Fat supply quantity (g/capita/day)          10102.77
# Protein supply quantity (g/capita/day)      11779.69
# Seed                                        23389.20
# Stock Variation                             33140.12
# Residuals                                   37224.00
# Food supply quantity (kg/capita/yr)         48985.28
# Other uses (non-food)                       69563.68
# Export Quantity                            151920.46
# Losses                                     157787.00
# Feed                                       228958.65
# Processing                                 280631.00
# Import Quantity                            286582.78
# Food supply (kcal/capita/day)              451810.00
# Total Population - Both sexes             1085107.00
# Food                                      1247022.17
# Production                                1943537.15
# Domestic supply quantity                  2044842.70
# ...

# %%
df.groupby("Element")["Y2015"].sum().sort_values(ascending=True)
# Out:
# Element
# Tourist consumption                           349.00
# Fat supply quantity (g/capita/day)          10235.74
# Protein supply quantity (g/capita/day)      11833.95
# Seed                                        23976.82
# Residuals                                   30045.00
# Stock Variation                             34910.99
# Food supply quantity (kg/capita/yr)         49345.13
# Other uses (non-food)                       66254.41
# Losses                                     155439.00
# Export Quantity                            157614.47
# Feed                                       225050.22
# Import Quantity                            267018.46
# Processing                                 287929.00
# Food supply (kcal/capita/day)              453383.00
# Total Population - Both sexes             1058081.00
# Food                                      1232361.10
# Production                                1947019.39
# Domestic supply quantity                  2021493.55
# ...

# %%
df.groupby("Element")["Y2014"].sum().sort_values(ascending=True)
# Out:
# Element
# Tourist consumption                           416.00
# Fat supply quantity (g/capita/day)          10225.56
# Protein supply quantity (g/capita/day)      11836.46
# Seed                                        21922.92
# Residuals                                   30149.00
# Food supply quantity (kg/capita/yr)         49650.63
# Stock Variation                             58749.83
# Other uses (non-food)                       78718.13
# Export Quantity                            150020.64
# Losses                                     153223.00
# Feed                                       216927.89
# Import Quantity                            274144.48
# Processing                                 282923.00
# Food supply (kcal/capita/day)              454257.00
# Total Population - Both sexes             1031585.00
# Food                                      1212332.49
# Production                                1931287.75
# Domestic supply quantity                  1996716.35
# ...

# %%
df.groupby("Area")["Y2017"].sum().sort_values(ascending=False)
# Out:
# Area
# Nigeria                        1483268.23
# Egypt                           866379.92
# South Africa                    517590.54
# Ethiopia                        448683.76
# Morocco                         388495.36
# Ghana                           337599.06
# Algeria                         325644.27
# United Republic of Tanzania     322616.85
# Kenya                           264660.66
# Sudan                           239931.92
# Cameroon                        232030.43
# Angola                          229159.57
# Côte d'Ivoire                   224599.01
# Uganda                          213950.38
# Malawi                          181098.71
# Mozambique                      161407.98
# Mauritania                      156665.46
# Mali                            149928.33
# Madagascar                      131197.73
# Niger                           126707.58
# Benin                           124771.22
# Tunisia                         124167.20
# ...

# %%
df.corr()
# Out:
# C:\Users\mainac\AppData\Local\Temp\ipykernel_9664\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# ...

# %%
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# Out:
# C:\Users\mainac\AppData\Local\Temp\ipykernel_9664\3160324439.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
# <Axes: >

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df["Item"].unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...

# %%
# Out:
# C:\Users\mainac\AppData\Local\Temp\ipykernel_9664\1487255084.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...
